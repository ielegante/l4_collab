# %% [markdown]
# # Elephant-L4 experiments notebook

# %%
import json
import datetime
import time
import ast

# %%
API_KEY = ''

# %%
# We use Langchain's API to connect to Groq
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

# %%
# We set up the answer Pydantic class
# We get much better returns this way
from langchain_core.pydantic_v1 import BaseModel, Field


class L4Scenario(BaseModel):
    scenario: str = Field(description='Rich and realistic factual matrix in which this provision might come up.')
    outcome: str = Field(description='Realistic outcome when applying the provision.')
    edge_case: str = Field(description='Edge case of a rich and realistic factual matrix where interpretation of the provision might be hairy.')

# %%
model = ChatGroq(temperature=0, groq_api_key=API_KEY, model_name="llama3-70b-8192")
structured_llm = model.with_structured_output(L4Scenario)

# %%
# Test-run
system = """You are a helpful, experienced, expert, legal academic, with a lot of life experience.
You will be shown a legal provision.
Be as detailed, comprehensive as possible.
Return the L4Scenario only.
"""
# we can take the last line out to be brief.
human = "{text}"
prompt = ChatPromptTemplate.from_messages([("system", system), ("human", human)])

chain = prompt | structured_llm

# %%
# Load all acts to find the latest one
# We used the version that has all legislation data compressed
# For faster load times
acts = []
with open('2024-05-17-acts_no-content.jl', 'r') as f:
    for line in f:
        acts.append(json.loads(line))

# %%
# get only acts that are current
latest_date = 0
dates = []
for n, act in enumerate(acts):
    key = [i for i in act.keys()][0]
    doc_status = act[key]['doc_status']
    # print(doc_status)
    if doc_status == 'Current':
        # print(key)
        # check unix timestamp
        # extract from e.g. ASA2007-/Date(1680278400000)/
        date = key.split('/')[1]
        date = date.split('(')[1]
        date = date.replace(')', '')
        # dates.append((n, date))
        date = int(date)
        if date > latest_date:
            latest_date = date
            # print(date)
            latest_act = key
# print(type(latest_date), latest_date)
latest_date_plaintext = datetime.datetime.fromtimestamp(int(latest_date)/1000).strftime('%Y-%m-%d')
print(latest_act, latest_date_plaintext)
# Out:
# TCA2005-/Date(1715270400000)/ 2024-05-10

# %%
# load the relevant xml file
with open('TCA2005-Date(1715270400000)_alt.json', 'r') as f:
    test_act = json.load(f)

# %%
test_act
# Out:
# {'provisions': [{'id': 'No ID',
#    'number': '1',
#    'headers': [],
#    'text': ['1.\xa0\xa0This Act is the Trust Companies Act 2005.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P11-',
#      'number': 'PART 1',
#      'header': 'PRELIMINARY'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '2',
#    'headers': [],
#    'text': ['2.\xa0\xa0In this Act, unless the context otherwise requires\xa0—“advocate and solicitor” means an advocate and solicitor of the Supreme Court or a foreign lawyer as defined in section\xa02(1) of the Legal Profession Act\xa01966;“Authority” means the Monetary Authority of Singapore established under the Monetary Authority of Singapore Act\xa01970;“book” includes any record, register, account, deed, writing and information, however compiled, recorded or stored, whether in written or printed form or on microfilm or in any other electronic form or otherwise;“capital markets products” has the meaning given by section\xa02(1) of the Securities and Futures Act\xa02001;“chief executive”, in relation to a licensed trust company, means any person, by whatever name described, who\xa0—(a)is in the direct employment of, or acting for or by arrangement with, the licensed trust company; and(b)is principally responsible for the management and conduct of the business of the licensed trust company;“collective investment scheme” has the meaning given by section\xa02(1) of the Securities and Futures Act\xa02001;“controller”, in relation to a licensed trust company, means a 20% controller, a 50% controller or an indirect controller as defined in section\xa016(3);“corporation” has the meaning given by section\xa04(1) of the Companies Act\xa01967;“director” has the meaning given by section\xa04(1) of the Companies Act\xa01967;“executive officer”, in relation to a licensed trust company, means any person, by whatever name described, who\xa0—(a)is in the direct employment of, or acting for or by arrangement with, the licensed trust company; and(b)is concerned with or takes part in the management of the licensed trust company on a day‑to‑day basis;“exempt person” means a person who is exempt under section\xa015 from holding a licence for the carrying on of any trust business;“financial year” has the meaning given by section\xa04(1) of the Companies Act\xa01967;“futures contract” has the meaning given by section\xa02(1) of the Securities and Futures Act\xa02001;“licensed trust company” means a corporation holding a trust business licence;“officer” has the meaning given by section\xa04(1) of the Companies Act\xa01967;“parent supervisory authority”, in relation to a licensed trust company incorporated outside Singapore, means the supervisory authority which is responsible, under the laws of the country or territory where the licensed trust company is incorporated, formed or established, for supervising the licensed trust company;“protected party”, in relation to a trust company, means a trust for which the trust company provides trust business services and includes the settlor and beneficiary under the trust;“related corporation” has the meaning given by section\xa04(1) of the Companies Act\xa01967;“resident manager” means an individual resident in Singapore who, under the immediate authority of the directors of a licensed trust company, is responsible for the conduct of the trust business of the licensed trust company;“securities” has the meaning given by section\xa02(1) of the Securities and Futures Act\xa02001;“specified securities-based derivatives contract” has the meaning given by section\xa02(1) of the Securities and Futures Act\xa02001;“substantial shareholder” has the meaning given by Division\xa04 of Part\xa04 of the Companies Act\xa01967;“trust business” means any business specified in the First\xa0Schedule;“trust business licence” means a licence granted by the Authority under section\xa05 that authorises the holder of the licence to carry on trust business;“trust business service” means any service in respect of any business specified in the First\xa0Schedule;“unit” has the meaning given by section\xa02(1) of the Securities and Futures Act\xa02001;“written directions” means written directions issued by the Authority under section\xa076.[2/2007; 10/2013; 4/2017]'],
#    'amendments': ['[2/2007; 10/2013; 4/2017]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P11-',
#      'number': 'PART 1',
#      'header': 'PRELIMINARY'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '3',
#    'headers': [],
#    'text': ['3.—(1)\xa0\xa0Subject to subsection\xa0(3), a person must not carry on any trust business or hold himself, herself or itself out as carrying on any trust business in or from within Singapore unless that person is a licensed trust company.(2)\xa0\xa0A licensed trust company must not, without the prior approval of the Authority, establish a place of business outside Singapore to carry on any business which, if carried on in Singapore, would constitute trust business.(3)\xa0\xa0Subsection\xa0(1) does not apply to any person specified in the Second\xa0Schedule.(4)\xa0\xa0Any person who contravenes subsection\xa0(1) or (2) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $75,000 or to imprisonment for a term not exceeding 3\xa0years or to both and, in the case of a continuing offence, to a further fine not exceeding $7,500 for every day or part of a day during which the offence continues after conviction.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '4',
#    'headers': [],
#    'text': ['4.—(1)\xa0\xa0An application for a trust business licence must\xa0—(a)be made to the Authority in such form and manner as the Authority may require; and(b)be accompanied by the prescribed application fee, which is non‑refundable and which must be paid in the manner specified by the Authority.(2)\xa0\xa0The Authority may require an applicant to provide it with such information or documents as it considers necessary in relation to the application.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '5',
#    'headers': [],
#    'text': ['5.—(1)\xa0\xa0The Authority must not grant a trust business licence to an applicant therefor unless the applicant is\xa0—(a)a company incorporated under the Companies Act\xa01967; or(b)a foreign company registered under Division\xa02 of Part\xa011 of the Companies Act\xa01967.(2)\xa0\xa0A trust business licence may only be granted if the applicant meets such minimum financial and other requirements as the Authority may prescribe.(3)\xa0\xa0Subject to regulations made under this Act, where an application is made for the grant of a trust business licence, the Authority may refuse the application if\xa0—(a)the applicant has not provided the Authority with such information or document as the Authority may require in relation to\xa0—(i)the applicant or any person employed by or associated with the applicant for the purposes of its trust business; or(ii)any circumstances likely to affect the manner in which the applicant conducts its trust business;(b)any information or document that is provided by the applicant to the Authority is false or misleading;(c)the applicant or its substantial shareholder is in the course of being wound up or otherwise dissolved, whether in Singapore or elsewhere;(d)an enforcement order against the applicant or its substantial shareholder in respect of a judgment debt has been returned unsatisfied in whole or in part;[Act 25 of 2021 wef 01/04/2022](e)a receiver, a receiver and manager, a judicial manager or an equivalent person has been appointed, whether in Singapore or elsewhere, in relation to or in respect of any property of the applicant or its substantial shareholder;(f)the applicant or its substantial shareholder has, whether in Singapore or elsewhere, entered into a compromise or scheme of arrangement with its creditors, being a compromise or scheme of arrangement that is still in operation;(g)the applicant or its substantial shareholder, or any officer of the applicant\xa0—(i)has been convicted, whether in Singapore or elsewhere, of any offence involving fraud or dishonesty or the conviction for which involved a finding that the applicant, substantial shareholder or officer had acted fraudulently or dishonestly; or(ii)has been convicted of an offence under this Act;(h)the Authority is not satisfied as to the educational or other qualification or experience of the officers or employees of the applicant having regard to the nature of the duties they are to perform if the applicant were granted the trust business licence;(i)the applicant fails to satisfy the Authority that it is a fit and proper person to be licensed or that all of its officers, employees and substantial shareholders are fit and proper persons;(j)the Authority has reason to believe that the applicant may not be able to act in the best interests of any protected party having regard to the reputation, character, financial integrity and reliability of the applicant or its officers, employees or substantial shareholders;(k)the Authority is not satisfied as to the financial standing of the applicant or its substantial shareholders or the manner in which the applicant’s trust business is to be conducted;(l)the Authority is not satisfied as to the record of past performance or expertise of the applicant, having regard to the nature of the trust business which the applicant may carry on if granted the trust business licence;(m)there are other circumstances which are likely\xa0—(i)to lead to the improper conduct of the applicant’s trust business by the applicant or any of its officers, employees or substantial shareholders; or(ii)to reflect discredit on the manner in which the applicant or its substantial shareholders conduct its trust business;(n)the Authority has reason to believe that the applicant, or any of its officers or employees, will not efficiently, honestly or fairly perform any of the activities or provide any of the services for which the applicant seeks to be licensed; or(o)the Authority is of the opinion that it w ...
#    'amendments': ['[Act 25 of 2021 wef 01/04/2022]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '6',
#    'headers': [],
#    'text': ['6.—(1)\xa0\xa0Every licensed trust company must pay to the Authority such licence fee as may be prescribed.(2)\xa0\xa0Any licence fee paid to the Authority under this Act is not to be refunded or remitted if\xa0—(a)the licence is revoked or suspended or lapses during the period to which the licence fee relates; or(b)the licensed trust company ceases to carry on trust business during the period to which the licence fee relates.(3)\xa0\xa0Despite subsection\xa0(2), the Authority may, where it considers appropriate, refund or remit the whole or part of any licence fee paid to it.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '7',
#    'headers': [],
#    'text': ['7.—(1)\xa0\xa0The Authority may grant a trust business licence subject to such conditions or restrictions as it thinks fit.(2)\xa0\xa0The Authority may, at any time, by written notice to a licensed trust company, vary or revoke any condition or restriction or attach such further condition or restriction as it thinks fit.(3)\xa0\xa0Any licensed trust company which contravenes any condition or restriction attached to its trust business licence shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $100,000 and, in the case of a continuing offence, to a further fine not exceeding $10,000 for every day or part of a day during which the offence continues after conviction.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '8',
#    'headers': [],
#    'text': ['8.\xa0\xa0Any person who, in connection with an application for a trust business licence and without reasonable excuse\xa0—(a)makes any statement which is false or misleading in a material particular; or(b)omits to state any matter or thing without which the application is misleading in a material respect,shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000 or to imprisonment for a term not exceeding 12\xa0months or to both.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '9',
#    'headers': [],
#    'text': ['9.—(1)\xa0\xa0Where\xa0—(a)a licensed trust company ceases to carry on any trust business;(b)any person has ceased to be a resident manager or a controller of a licensed trust company;(c)any civil or criminal proceedings have been instituted against a licensed trust company or any officer of the licensed trust company;(d)any change occurs in the name of a licensed trust company or the address of the principal place of business at which the licensed trust company carries on its trust business;(e)a licensed trust company has ceased to fulfil the minimum financial or other requirements prescribed by the Authority; or(f)any change occurs in relation to any other matters that may be prescribed,the licensed trust company must, not later than 14\xa0days after the occurrence of the event, provide particulars of the event to the Authority in the prescribed form and manner.(2)\xa0\xa0Where a licensed trust company ceases to carry on any trust business, it must, within 14\xa0days of the date of the cessation of its trust business, surrender to the Authority the trust business licence that has been granted to it.(3)\xa0\xa0Any licensed trust company which contravenes subsection\xa0(1) or (2) shall be guilty of an offence.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '10',
#    'headers': [],
#    'text': ['10.—(1)\xa0\xa0The trust business licence of a licensed trust company lapses\xa0—(a)if the licensed trust company is wound up or otherwise dissolved, whether in Singapore or elsewhere; or(b)in the event of such other occurrence or in such other circumstances as may be prescribed.(2)\xa0\xa0The Authority may revoke or suspend the trust business licence of a licensed trust company in respect to all or any of the trust business services that are provided by the licensed trust company if\xa0—(a)there exists a ground on which the Authority may refuse an application under section\xa05(3);(b)the licensed trust company fails or ceases to carry on any trust business;(c)the Authority has reason to believe that the licensed trust company, or any of its officers or employees, has not performed its, his or her duties efficiently, honestly or fairly;(d)the licensed trust company has contravened or is contravening\xa0—(i)any condition or restriction attached to its trust business licence;(ii)any direction issued to it by the Authority under this Act; or(iii)any provision of this Act;(e)upon the Authority exercising any power under section\xa021C(2) or the Minister exercising any power under Division 2, 4, 5 or 6 of Part 8 of the Financial Services and Markets Act 2022 in relation to the licensed trust company, the Authority considers that it is in the public interest to revoke or suspend the trust business licence;[Act 18 of 2022 wef 10/05/2024](f)any information or document that is provided by the licensed trust company to the Authority is false or misleading; or(g)the interests of the public or of the protected parties of the licensed trust company are in any way prejudiced.[10/2013; 31/2017](3)\xa0\xa0The Authority must not revoke or suspend the trust business licence of a licensed trust company under subsection\xa0(2) without giving the licensed trust company an opportunity to be heard, except in any of the following circumstances:(a)the licensed trust company is in the course of being wound up or otherwise dissolved, whether in Singapore or elsewhere;(b)a receiver, a receiver and manager, a judicial manager or an equivalent person has been appointed, whether in Singapore or elsewhere, in relation to or in respect of any property of the licensed trust company;(c)the licensed trust company has been convicted, whether in Singapore or elsewhere, of an offence involving fraud or dishonesty or the conviction for which involved a finding that it had acted fraudulently or dishonestly.'],
#    'amendments': ['[Act 18 of 2022 wef 10/05/2024]', '[10/2013; 31/2017]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '11',
#    'headers': [],
#    'text': ['11.—(1)\xa0\xa0A licensed trust company must not, without the sanction of the court and for so long as any trust in respect of which the licensed trust company is a trustee remains in whole or in part unadministered\xa0—(a)cease to carry on its trust business; or(b)surrender its trust business licence to the Authority.(2)\xa0\xa0Any licensed trust company which contravenes subsection\xa0(1) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $25,000 and, in the case of a continuing offence, to a further fine not exceeding $2,500 for every day or part of a day during which the offence continues after conviction.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '12',
#    'headers': [],
#    'text': ['12.—(1)\xa0\xa0The persons who may apply under the Insolvency, Restructuring and Dissolution Act\xa02018 for the winding up of the affairs of a licensed trust company, or for the continuance of the winding up of the affairs of a licensed trust company subject to the supervision of the court, include the Authority.[40/2018](2)\xa0\xa0The Authority may, in accordance with the provisions of the Insolvency, Restructuring and Dissolution Act\xa02018, apply for the winding up of a licensed trust company if the licensed trust company has contravened any provision of this Act.[40/2018](3)\xa0\xa0The Authority is to be a party to any proceedings under the Insolvency, Restructuring and Dissolution Act\xa02018 relating to the winding up of the affairs of a licensed trust company.[40/2018](4)\xa0\xa0The liquidator in any winding up mentioned in subsection\xa0(3) must give to the Authority such information as the Authority may, from time to time, require about the affairs of the licensed trust company.(5)\xa0\xa0Any liquidator who contravenes subsection\xa0(4) shall be guilty of an offence.'],
#    'amendments': ['[40/2018]', '[40/2018]', '[40/2018]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '13',
#    'headers': [],
#    'text': ['13.—(1)\xa0\xa0A licensed trust company must not appoint a person as\xa0—(a)its resident manager; or(b)its director where, upon appointment, the person\xa0—(i)resides or is to reside in Singapore, whether or not he or she is directly responsible for its business in Singapore or any part of such business; or(ii)is directly responsible for its business in Singapore or any part of such business, whether he or she resides in Singapore or elsewhere,unless it has obtained the approval of the Authority.(2)\xa0\xa0Where a licensed trust company has obtained the approval of the Authority to appoint a person as its resident manager or director under subsection\xa0(1), the person may be re‑appointed as resident manager or director (as the case may be) of the licensed trust company immediately upon the expiry of the earlier term without the approval of the Authority.(3)\xa0\xa0Without affecting any other matter that the Authority may consider relevant, the Authority may, in determining whether to grant its approval under subsection\xa0(1), have regard to such requirements as may be prescribed or as may be specified in written directions.(4)\xa0\xa0The Authority must not refuse an application for approval under subsection\xa0(1) without giving the licensed trust company an opportunity to be heard, except where the person proposed to be appointed\xa0—(a)is an undischarged bankrupt, whether in Singapore or elsewhere; or(b)has been convicted, whether in Singapore or elsewhere, of an offence\xa0—(i)involving fraud or dishonesty or the conviction for which involved a finding that he or she had acted fraudulently or dishonestly; and(ii)punishable with imprisonment for a term of 3\xa0months or more.(5)\xa0\xa0Where the Authority refuses an application for approval under subsection\xa0(1), the Authority need not give the person who was proposed to be appointed an opportunity to be heard.(6)\xa0\xa0Any licensed trust company which contravenes subsection\xa0(1) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '14',
#    'headers': [],
#    'text': ['14.—(1)\xa0\xa0Where the Authority is satisfied that an officer of a licensed trust company\xa0—(a)has wilfully contravened or wilfully caused the licensed trust company to contravene this Act;(b)has, without reasonable excuse, failed to enforce compliance with this Act;(c)has failed to discharge the duties or functions of the officer’s office;(d)is an undischarged bankrupt, whether in Singapore or elsewhere;(e)has had an enforcement order against the officer in respect of a judgment debt returned unsatisfied in whole or in part;[Act 25 of 2021 wef 01/04/2022](f)has, whether in Singapore or elsewhere, entered into a compromise or scheme of arrangement with the officer’s creditors, being a compromise or scheme of arrangement that is still in operation; or(g)has been convicted, whether in Singapore or elsewhere, of an offence involving fraud or dishonesty or the conviction for which involved a finding that the officer had acted fraudulently or dishonestly,the Authority may, if it thinks it necessary in the interest of the public or of the protected parties of the licensed trust company, by written notice direct that licensed trust company to remove the officer from office or employment, and that licensed trust company must comply with the notice despite the provisions of section\xa0152 of the Companies Act\xa01967.(2)\xa0\xa0Without affecting any other matter that the Authority may consider relevant, the Authority must, in determining whether an officer of a licensed trust company has failed to discharge the duties or functions of his or her office for the purposes of subsection\xa0(1)(c), have regard to such criteria as may be prescribed or as may be specified in written directions.(3)\xa0\xa0The Authority must not direct a licensed trust company to remove an officer from office or employment under subsection\xa0(1) without giving that licensed trust company an opportunity to be heard, except in the following circumstances:(a)the officer is an undischarged bankrupt, whether in Singapore or elsewhere;(b)the officer has been convicted, whether in Singapore or elsewhere, of an offence\xa0—(i)involving fraud or dishonesty or the conviction for which involved a finding that the officer had acted fraudulently or dishonestly; and(ii)punishable with imprisonment for a term of 3\xa0months or more.(4)\xa0\xa0Where the Authority directs a licensed trust company to remove an officer from office or employment under subsection\xa0(1), the Authority need not give that officer an opportunity to be heard.(5)\xa0\xa0No civil or criminal liability is incurred by\xa0—(a)a licensed trust company; or(b)any person acting on behalf of the licensed trust company,in respect of anything done or omitted to be done with reasonable care and in good faith in the discharge or purported discharge of its obligations under this section.(6)\xa0\xa0Any licensed trust company which fails to comply with a notice issued by the Authority under subsection\xa0(1) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000.'],
#    'amendments': ['[Act 25 of 2021 wef 01/04/2022]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '15',
#    'headers': [],
#    'text': ['15.—(1)\xa0\xa0Subject to subsection\xa0(9), the following persons are exempt from the requirement to hold a trust business licence in respect of the carrying on of trust business:(a)any bank licensed under the Banking Act\xa01970 in respect of\xa0—(i)the provision of services in relation to the creation of an express trust;(ii)the arrangement for any person to act as trustee in relation to an express trust; or(iii)the provision of trust administration services which are procedural and non‑discretionary;(b)any merchant bank licensed under the Banking Act\xa01970 in respect of\xa0—(i)the provision of services in relation to the creation of an express trust;(ii)the arrangement for any person to act as trustee in relation to an express trust; or(iii)the provision of trust administration services which are procedural and non-discretionary;(c)any holder of a capital markets services licence, or any person who is exempt from holding a capital markets services licence, for providing fund management or custodial services under the Securities and Futures Act\xa02001, in respect of the provision of fund management or custodial services;(d)any other person or class of persons that may be prescribed;(e)any other person not falling within the description of paragraphs\xa0(a) to (d) whom the Authority may, on the application of the person, by written notice so exempt.[4/2017; 1/2020](2)\xa0\xa0Any bank providing any trust business service referred to in subsection\xa0(1)(a)(i) or (ii) must\xa0—(a)within 3\xa0months from 1 February 2006 or one month from the date of commencement of its trust business, whichever is the later, notify the Authority in writing that it is providing such service; and(b)as soon as practicable, notify the Authority if it ceases to provide such service, but in any case no later than 14\xa0days from the date of cessation.(3)\xa0\xa0Any merchant bank providing any trust business service referred to in subsection\xa0(1)(b)(i) or (ii) must\xa0—(a)within 3\xa0months from 1 February 2006 or one month from the date of commencement of its trust business, whichever is the later, notify the Authority in writing that it is providing such service; and(b)as soon as practicable, notify the Authority if it ceases to provide such service, but in any case no later than 14\xa0days from the date of cessation.(4)\xa0\xa0The Authority may prescribe the provisions of this Act that apply to persons referred to in subsection\xa0(1)(a), (b) and (c).(5)\xa0\xa0The Authority may prescribe or specify in written directions the provisions of this Act that apply to persons mentioned in subsection\xa0(1)(d) and (e).(6)\xa0\xa0The Authority may prescribe or specify in written directions such conditions or restrictions as it thinks fit to impose on an exempt person in relation to the conduct of trust business or any related matter as the Authority thinks fit and the exempt person must comply with such conditions or restrictions.(7)\xa0\xa0The Authority may at any time vary, rescind or revoke any written direction issued under subsection\xa0(5) or (6).(8)\xa0\xa0Any exempt person who contravenes\xa0—(a)subsection\xa0(2) or (3);(b)any applicable provision of this Act as prescribed under subsection\xa0(4) or (5) in relation to the exempt person; or(c)any condition or restriction imposed under subsection\xa0(6),shall be guilty of an offence and shall be liable on conviction\xa0—(d)in the case of a contravention of any applicable provision of this Act, to the same penalties as are prescribed under this Act for any such contravention; and(e)in the case of a contravention of subsection\xa0(2) or (3) or a contravention of any condition or restriction imposed under subsection\xa0(6), to a fine not exceeding $50,000 and, in the case of a continuing offence, to a further fine not exceeding $5,000 for every day or part of a day during which the offence continues after conviction.(9)\xa0\xa0The Authority may revoke an exemption conferred on any perso ...
#    'amendments': ['[4/2017; 1/2020]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P12-',
#      'number': 'PART 2',
#      'header': 'LICENSING OF TRUST COMPANIES'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '16',
#    'headers': [],
#    'text': ['16.—(1)\xa0\xa0A person must not become\xa0—(a)a 20% controller;(b)a 50% controller; or(c)an indirect controller,of a licensed trust company incorporated in Singapore without obtaining the prior approval of the Authority in accordance with section\xa017.(2)\xa0\xa0Where any person becomes a controller of a licensed trust company that is incorporated outside Singapore, the licensed trust company must notify the Authority in writing as soon as practicable after the acquisition of the control.(3)\xa0\xa0In this section\xa0—“20% controller” means a person who, alone or together with the person’s associates\xa0—(a)holds 20% or more but less than 50% of the total number of issued shares in the licensed trust company; or(b)is in a position to control voting power of 20% or more but less than 50% in the licensed trust company;“50% controller” means a person who, alone or together with the person’s associates\xa0—(a)holds 50% or more of the total number of issued shares in the licensed trust company; or(b)is in a position to control voting power of 50% or more in the licensed trust company;“indirect controller” means any person, whether acting alone or together with any other person and whether with or without holding shares or controlling voting power in a licensed trust company\xa0—(a)in accordance with whose directions, instructions or wishes the directors of the licensed trust company are accustomed or under an obligation, whether formal or informal, to act; or(b)who is in a position to determine the policy of the licensed trust company,but does not include any person\xa0—(c)who is a director or other officer of the licensed trust company whose appointment has been approved by the Authority; or(d)in accordance with whose directions, instructions or wishes the directors of the licensed trust company are accustomed to act by reason only that they act on advice given by the person in the person’s professional capacity.(4)\xa0\xa0For the purposes of subsection\xa0(3)\xa0—(a)a person holds a share if\xa0—(i)the person is deemed to have an interest in that share under section\xa07(6) to (10) of the Companies Act\xa01967; or(ii)the person otherwise has a legal or an equitable interest in that share except for such interest as is to be disregarded under section\xa07(6) to (10) of the Companies Act\xa01967;(b)a reference to the control of a percentage of the voting power in a licensed trust company is a reference to the control, whether direct or indirect, of that percentage of the total number of votes that might be cast in a general meeting of the licensed trust company; and(c)a person, A, is an associate of another person, B, if\xa0—(i)A is the spouse or a parent, remoter lineal ancestor or step‑parent or a son, daughter, remoter issue, stepson or stepdaughter or a brother or sister, of B;(ii)A is a body corporate that is, or a majority of the directors of which are, accustomed or under an obligation whether formal or informal to act in accordance with the directions, instructions or wishes of B;(iii)A is a person who is accustomed or under an obligation, whether formal or informal, to act in accordance with the directions, instructions or wishes of B;(iv)A is a subsidiary of B;(v)A is a body corporate in which B, alone or together with other associates of B as described in sub‑paragraphs\xa0(ii), (iii) and (iv), is in a position to control at least 20% of the voting power in A; or (vi)A is a person with whom B has an agreement or arrangement, whether oral or in writing and whether express or implied, to act together with respect to the acquisition, holding or disposal of shares or other interests in, or with respect to the exercise of their voting power in relation to, the licensed trust company.[35/2014](5)\xa0\xa0In subsection\xa0(4)(c), “subsidiary” has the meaning given by section\xa05 of the Companies Act\xa01967.[35/2014]'],
#    'amendments': ['[35/2014]', '[35/2014]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13-',
#      'number': 'PART 3',
#      'header': 'CONTROL OF SHAREHOLDINGS AND VOTING POWERS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '17',
#    'headers': [],
#    'text': ['17.—(1)\xa0\xa0An application for the approval of the Authority as required under section\xa016(1) must be made to the Authority in such form and manner as the Authority may require and the Authority may grant such approval to the applicant therefor if the Authority is satisfied that\xa0—(a)the applicant is a fit and proper person; and(b)having regard to the applicant’s likely influence, the licensed trust company is likely to continue to conduct its business prudently and comply with the provisions of this Act and directions made under this Act.(2)\xa0\xa0Any approval under this section may be granted to any person subject to such conditions as the Authority may determine, including but not limited to any condition\xa0—(a)restricting the person’s disposal or further acquisition of shares or voting power in the licensed trust company; or(b)restricting the person’s exercise of voting power in the licensed trust company.(3)\xa0\xa0Any condition imposed under subsection\xa0(2) has effect despite any provision of the Companies Act\xa01967 or anything contained in the memorandum or articles of association of the licensed trust company.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13-',
#      'number': 'PART 3',
#      'header': 'CONTROL OF SHAREHOLDINGS AND VOTING POWERS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '18',
#    'headers': [],
#    'text': ['18.—(1)\xa0\xa0The Authority may serve a written notice of objection on any person mentioned in section\xa016 if the Authority is satisfied that\xa0—(a)any condition of approval imposed on the person under section\xa017(2) has not been complied with;(b)the person is not or ceases to be a fit and proper person;(c)having regard to the likely influence of the person, the licensed trust company is not able to or is no longer likely to conduct its business prudently or to comply with the provisions of this Act or any direction made under this Act;(d)the person has provided false or misleading information or documents in connection with an application under section\xa017; or(e)the Authority would not have granted its approval under section\xa017 had it been aware, at that time, of circumstances relevant to the person’s application for such approval.(2)\xa0\xa0The Authority must not serve a notice of objection on any person without giving the person an opportunity to be heard, except in the following circumstances:(a)the person is in the course of being wound up or otherwise dissolved, or in the case of an individual, in the course of bankruptcy proceedings, whether in Singapore or elsewhere;(b)a receiver, a receiver and manager, a judicial manager or an equivalent person has been appointed, whether in Singapore or elsewhere, in relation to or in respect of any property of the person;(c)the person has been convicted, whether in Singapore or elsewhere, of any offence involving fraud or dishonesty or the conviction for which involved a finding that the person had acted fraudulently or dishonestly.(3)\xa0\xa0Any person served with a notice of objection under this section must comply with the requirements of the notice.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13-',
#      'number': 'PART 3',
#      'header': 'CONTROL OF SHAREHOLDINGS AND VOTING POWERS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '19',
#    'headers': [],
#    'text': ['19.\xa0\xa0A licensed trust company must provide to the Authority, in such form and manner as the Authority may prescribe, information relating to its controllers and the quantity of their control in the licensed trust company.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13-',
#      'number': 'PART 3',
#      'header': 'CONTROL OF SHAREHOLDINGS AND VOTING POWERS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '20',
#    'headers': [],
#    'text': ['20.—(1)\xa0\xa0Any person who contravenes section\xa016(1), 18(3) or 19 or any condition imposed under section\xa017(2) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000.(2)\xa0\xa0Where a person is charged with an offence in respect of a contravention of section\xa016(1), it is a defence for the person to prove that\xa0—(a)the person was not aware that the person had contravened that provision; and(b)the person has, within 14\xa0days of becoming aware that the person had contravened that provision, notified the Authority of the contravention and, within the time determined by the Authority, taken such actions in relation to the person’s shareholding or control of the voting power in the licensed trust company as the Authority may direct.(3)\xa0\xa0Where a person is charged with an offence in respect of a contravention of section\xa016(1), it is also a defence for the person to prove that, even though the person was aware of the contravention\xa0—(a)the contravention occurred as a result of an increase in the shareholding as described in section\xa016(4)(a) or in the voting power controlled by any of the person’s associates described in section\xa016(4)(c)(i);(b)the person has no agreement or arrangement, whether oral or in writing and whether express or implied, with that associate with respect to the acquisition, holding or disposal of shares or other interests in, or under which they act together in exercising their voting power in relation to, the licensed trust company; and(c)the person has, within 14\xa0days of the date of the contravention, notified the Authority of the contravention and, within such time as may be determined by the Authority, taken such action in relation to the person’s shareholding or control of the voting power in the licensed trust company as the Authority may direct.(4)\xa0\xa0Except as provided in subsections\xa0(2) and (3), it is not a defence for a person charged with an offence in respect of a contravention of section\xa016(1) to prove that the person did not intend to or did not knowingly contravene that provision.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13-',
#      'number': 'PART 3',
#      'header': 'CONTROL OF SHAREHOLDINGS AND VOTING POWERS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '21',
#    'headers': [],
#    'text': ['21.—(1)\xa0\xa0A licensed trust company must not, without obtaining the prior approval of the Authority, acquire or hold more than\xa0—(a)20% of the total number of issued shares; or(b)20% of the voting power,in a corporation, unless it acquires or holds such shares or voting power in the course of acting as a trustee.(2)\xa0\xa0Any licensed trust company which contravenes subsection\xa0(1) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13-',
#      'number': 'PART 3',
#      'header': 'CONTROL OF SHAREHOLDINGS AND VOTING POWERS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '21A',
#    'headers': [],
#    'text': ['21A.\xa0\xa0In this Part, unless the context otherwise requires —“business” includes affairs and property;“office holder”, in relation to a licensed trust company, means any person acting as the liquidator, the provisional liquidator, the receiver or the receiver and manager of the licensed trust company, or acting in an equivalent capacity in relation to the licensed trust company;“relevant business” means any business of a licensed trust company\xa0—(a)which the Authority has assumed control of under section\xa021C; or(b)in relation to which a statutory adviser or a statutory manager has been appointed under section\xa021C;“statutory adviser” means a statutory adviser appointed under section\xa021C;“statutory manager” means a statutory manager appointed under section\xa021C.[10/2013]'],
#    'amendments': ['[10/2013]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13A-',
#      'number': 'PART 3A',
#      'header': 'CONTROL OVER LICENSED TRUST COMPANY'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '21B',
#    'headers': [],
#    'text': ['21B.—(1)\xa0\xa0Any licensed trust company which is or is likely to become insolvent, which is or is likely to become unable to meet its obligations, or which has suspended or is about to suspend payments, must immediately inform the Authority of that fact.[10/2013](2)\xa0\xa0Any licensed trust company which contravenes subsection\xa0(1) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000 and, in the case of a continuing offence, to a further fine not exceeding $5,000 for every day or part of a day during which the offence continues after conviction.[10/2013]'],
#    'amendments': ['[10/2013]', '[10/2013]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13A-',
#      'number': 'PART 3A',
#      'header': 'CONTROL OVER LICENSED TRUST COMPANY'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '21C',
#    'headers': [],
#    'text': ['21C.—(1)\xa0\xa0The Authority may exercise any one or more of the powers specified in subsection\xa0(2) as appears to it to be necessary, where\xa0—(a)a licensed trust company informs the Authority that it is or is likely to become insolvent, or that it is or is likely to become unable to meet its obligations, or that it has suspended or is about to suspend payments;(b)a licensed trust company becomes unable to meet its obligations, or is insolvent, or suspends payments;(c)the Authority is of the opinion that a licensed trust company\xa0—(i)is carrying on its business in a manner likely to be detrimental to the interests of the public or a section of the public or of the protected parties of the licensed trust company;(ii)is or is likely to become insolvent, or is or is likely to become unable to meet its obligations, or is about to suspend payments;(iii)has contravened any of the provisions of this Act; or(iv)has failed to comply with any condition or restriction attached to its trust business licence; or(d)the Authority considers it in the public interest to do so.[10/2013](2)\xa0\xa0Subject to subsections (1) and (3), the Authority may\xa0—(a)require the licensed trust company immediately to take any action or to do or not to do any act or thing whatsoever in relation to its business as the Authority may consider necessary;(b)appoint one or more persons as statutory adviser, on such terms and conditions as the Authority may specify, to advise the licensed trust company on the proper management of such of the business of the licensed trust company as the Authority may determine; or(c)assume control of and manage such of the business of the licensed trust company as the Authority may determine, or appoint one or more persons as statutory manager to do so on such terms and conditions as the Authority may specify.[10/2013](3)\xa0\xa0In the case of a licensed trust company incorporated outside Singapore, any appointment of a statutory adviser or statutory manager or any assumption of control by the Authority of any business of the licensed trust company under subsection\xa0(2) must only be in relation to\xa0—(a)the business or affairs of the licensed trust company carried on in, or managed in or from, Singapore; or(b)the property of the licensed trust company located in Singapore, or reflected in the books of the licensed trust company in Singapore (as the case may be) in relation to its operations in Singapore.[10/2013](4)\xa0\xa0Where the Authority appoints 2 or more persons as the statutory manager of a licensed trust company, the Authority must specify, in the terms and conditions of the appointment, which of the duties, functions and powers of the statutory manager\xa0—(a)may be discharged or exercised by such persons jointly and severally;(b)must be discharged or exercised by such persons jointly; and(c)must be discharged or exercised by a specified person or such persons.[10/2013](5)\xa0\xa0Where the Authority has exercised any power under subsection\xa0(2), it may, at any time and without affecting its power under section\xa010(2)(e), do one or more of the following:(a)vary or revoke any requirement of, any appointment made by or any action taken by the Authority in the exercise of such power, on such terms and conditions as it may specify;(b)further exercise any of the powers under subsection\xa0(2);(c)add to, vary or revoke any term or condition specified by the Authority under this section.[10/2013](6)\xa0\xa0No liability shall be incurred by a statutory manager or a statutory adviser for anything done (including any statement made) or omitted to be done with reasonable care and in good faith in the course of or in connection with\xa0—(a)the exercise or purported exercise of any power under this Act;(b)the performance or purported performance of any function or duty under this Act; or(c)the compliance or purported compliance with this Act.[10/2013](7)\xa0\xa0Any licensed trust company that fails to comply ...
#    'amendments': ['[10/2013]',
#     '[10/2013]',
#     '[10/2013]',
#     '[10/2013]',
#     '[10/2013]',
#     '[10/2013]',
#     '[10/2013]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P13A-',
#      'number': 'PART 3A',
#      'header': 'CONTROL OVER LICENSED TRUST COMPANY'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '21D',
#    'headers': [],
# ...
#    'amendments': ['[10/2013]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '75',
#    'headers': [],
#    'text': ['75.—(1)\xa0\xa0The Authority may, where it thinks it necessary or expedient in the interest of the public, a section of the public or the protected parties of licensed trust companies, publish in such form and manner as it thinks fit\xa0—(a)any information relating to\xa0—(i)any licensed trust company;(ii)any exempt person; or(iii)any other person or class of persons granted an exemption under section\xa080; or(b)any other information which the Authority has acquired in the exercise of its functions or the performance of its duties under this Act.(2)\xa0\xa0Without limiting subsection\xa0(1), the Authority may publish information relating to\xa0—(a)the lapsing, revocation or suspension of the approval, licence or exemption granted to any person referred to in subsection\xa0(1);(b)the removal of an officer of any person referred to in subsection\xa0(1);(c)the composition of any offence\xa0—(i)under this Act committed by any person; or(ii)under any other law (whether of Singapore or any territory or country outside Singapore) involving a person referred to in subsection\xa0(1);(d)any civil or criminal proceedings brought\xa0—(i)under this Act against any person and the outcome of the proceedings, including any settlement, whether in or out of court; or(ii)under any other law, whether of Singapore or any territory or country outside Singapore, against any person referred to in subsection\xa0(1) and the outcome of the proceedings, including any settlement, whether in or out of court;(e)any disciplinary proceedings brought by the Authority against any person referred to in subsection\xa0(1) and the outcome of the proceedings; and(f)any other action as may have been taken by the Minister or the Authority against any person referred to in subsection\xa0(1).'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '76',
#    'headers': [],
#    'text': ['76.—(1)\xa0\xa0The Authority may, if it thinks it necessary or expedient in the interest of the public or the protected parties of licensed trust companies, issue written directions, either of a general or specific nature, to\xa0—(a)any licensed trust company;(b)any exempt person;(c)any officer of a licensed trust company or an exempt person; or(d)any class of the persons referred to in paragraphs\xa0(a), (b) or (c),to comply with such requirements as the Authority may specify in the written directions.(2)\xa0\xa0Without limiting subsection\xa0(1), any written direction may be issued with respect to\xa0—(a)the standards to be maintained by the licensed trust company or exempt person concerned in the conduct of the business of the licensed trust company or exempt person;(b)the type and frequency of submission of financial returns and other information to be submitted to the Authority; and(c)the qualifications, experience and training of the officers of the licensed trust company or exempt person,and the person to whom the direction is issued must comply with the direction.(3)\xa0\xa0Any person who contravenes any direction issued under subsection\xa0(1) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000 and, in the case of a continuing offence, to a further fine of $5,000 for every day or part of a day during which the offence continues after conviction.(4)\xa0\xa0It is not necessary to publish any direction issued under subsection\xa0(1) in the Gazette.[10/2013](5)\xa0\xa0The Authority may at any time vary, rescind or revoke any written direction under subsection\xa0(1).'],
#    'amendments': ['[10/2013]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '77',
#    'headers': [],
#    'text': ['77.—(1)\xa0\xa0Where on the application of the Authority, it appears to the court that a person\xa0—(a)has committed an offence under this Act;(b)has contravened any condition or restriction of a trust business licence; or(c)is about to do an act that, if done, would be such an offence or contravention,the court may, without affecting any order it would be entitled to make otherwise than under this section, make one or more of the following orders:(d)in the case of a persistent or continuing breach of this Act or of any condition or restriction of a licence, an order restraining a person from carrying on all or any of the trust business or from holding the person out as so carrying on all or any of the trust business or so acting;(e)for the purpose of securing compliance with any other order under this section, an order directing a person to do or refrain from doing a specified act;(f)any ancillary order deemed to be necessary or desirable in consequence of the making of any of these orders.(2)\xa0\xa0The court may, before making an order under subsection\xa0(1), direct that notice of the application be given to such person as the court thinks fit or that notice of the application be published in such manner as it thinks fit, or both.(3)\xa0\xa0Any person who, without reasonable excuse, contravenes an order made under subsection\xa0(1) shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000 or to imprisonment for a term not exceeding 2\xa0years or to both.(4)\xa0\xa0Subsection\xa0(3) does not affect the powers of the court in relation to the punishment for contempt of court.(5)\xa0\xa0The court may, on the application of an affected person or of its own motion, rescind, vary or discharge an order made by the court under this section or suspend the operation of such an order.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '78',
#    'headers': [],
#    'text': ['78.—(1)\xa0\xa0Where a person has engaged, is engaging or is likely to engage in any conduct that constitutes or would constitute a contravention of this Act, the court may, on the application of the Authority, grant an injunction restraining the person from engaging in the conduct and, if the court is of the opinion that it is desirable to do so, requiring that person to do any act or thing.(2)\xa0\xa0Where a person has refused or failed, is refusing or failing, or is likely to refuse or fail, to do an act or thing that the person is required by this Act to do, the court may, on the application of the Authority, make an order requiring the person to do that act or thing.(3)\xa0\xa0Where an application is made to the court for an injunction under subsection\xa0(1) or an order under subsection\xa0(2), the court may, if the court is of the opinion that it is desirable to do so, before considering the application, grant an interim injunction restraining a person from engaging in conduct of the kind referred to in subsection\xa0(1) or make an interim order requiring a person to do any act or thing, pending the determination of the application.(4)\xa0\xa0Where the court has granted an injunction or interim injunction or made an order or interim order under this section, the court may, on application by the Authority or by any person affected by the injunction, order, interim injunction or interim order, rescind or vary the injunction, order, interim injunction or interim order.(5)\xa0\xa0An injunction, order, interim injunction or interim order granted or made under this section may be expressed to operate for a period specified in the injunction, order, interim injunction or interim order or until the injunction, order, interim injunction or interim order is rescinded.(6)\xa0\xa0Any person who contravenes an injunction, order, interim injunction or interim order that is granted or made by the court under this section that is applicable to the person shall be guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000 or to imprisonment for a term not exceeding 2\xa0years or to both.(7)\xa0\xa0Where an application is made to the court for the grant of an injunction under subsection\xa0(1), the power of the court to grant the injunction may be exercised\xa0—(a)if the court is satisfied that the person has engaged in conduct of that kind referred to in that subsection, whether or not it appears to the court that the person intends to engage again, or to continue to engage, in conduct of that kind; or(b)if it appears to the court that, in the event that an injunction is not granted, it is likely that the person will engage in conduct of that kind referred to in that subsection, whether or not the person has previously engaged in conduct of that kind and whether or not there is an imminent danger of substantial damage to any person if the firstmentioned person engages in conduct of that kind.(8)\xa0\xa0Where an application is made to the court for the making of an order under subsection\xa0(2), the power of the court to make the order may be exercised\xa0—(a)if the court is satisfied that the person has refused or failed to do that act or thing mentioned in that subsection, whether or not it appears to the court that the person intends to refuse or fail again, or to continue to refuse or fail, to do that act or thing; or(b)if it appears to the court that, in the event that an order is not made, it is likely the person will refuse or fail to do that act or thing mentioned in that subsection, whether or not the person has previously refused or failed to do that act or thing and whether or not there is an imminent danger of substantial damage to any person if the firstmentioned person refuses or fails to do that act or thing.(9)\xa0\xa0Where the Authority makes an application to the court for the grant of an injunction or interim injunction or for the making of an order or interim order under this s ...
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '79',
#    'headers': [],
#    'text': ['79.—(1)\xa0\xa0Any notice or direction to be given or served by the Authority on a person is for all purposes regarded as duly given or served if it has been delivered or sent by post or fax transmission to the person at the person’s last known address.(2)\xa0\xa0In the case of a corporation, the last known address mentioned in subsection\xa0(1) is\xa0—(a)if it is a company incorporated in Singapore, the address of its registered office in Singapore; or(b)if it is a foreign company, the address of its registered office in Singapore or the registered address of its authorised representative, referred to in section\xa0366(1) of the Companies Act\xa01967, or, if it does not maintain a place of business in Singapore, its registered office in the place of its incorporation.[35/2014]'],
#    'amendments': ['[35/2014]'],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '80',
#    'headers': [],
#    'text': ['80.—(1)\xa0\xa0The Authority may, by regulations, exempt any person or any class of persons, from all or any of the provisions of this Act, subject to such conditions or restrictions as may be prescribed.(2)\xa0\xa0The Authority may, on the application of any person, by written notice exempt the person from all or any of the provisions of this Act or the requirements specified in any written direction made by the Authority under this Act if the Authority considers it appropriate to do so in the circumstances of the case.(3)\xa0\xa0An exemption granted under subsection\xa0(2)\xa0—(a)may be granted subject to such conditions or restrictions as the Authority may specify by written notice;(b)need not be published in the Gazette; and(c)may be withdrawn at any time by the Authority.(4)\xa0\xa0Any person who contravenes any condition or restriction imposed under subsection\xa0(1) or (3)(a) shall be guilty of an offence.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '81',
#    'headers': [],
#    'text': ['81.—(1)\xa0\xa0The Minister may, by order in the Gazette, amend, add to or vary any of Schedules.(2)\xa0\xa0The Minister may, in any order made under subsection\xa0(1), make such incidental, consequential or supplementary provisions to the Act as may be necessary or expedient.(3)\xa0\xa0Any order made under subsection\xa0(1) must be presented to Parliament as soon as possible after publication in the Gazette.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}},
#   {'id': 'No ID',
#    'number': '82',
#    'headers': [],
#    'text': ['82.—(1)\xa0\xa0The Authority may make regulations for carrying out the purposes and provisions of this Act and for the due administration of this Act.(2)\xa0\xa0Without limiting subsection\xa0(1), the Authority may make regulations for or with respect to\xa0—(a)applications for the grant of licences under this Act and matters incidental thereto;(b)the minimum financial and other requirements that an applicant must fulfil for it to be issued a licence under this Act;(c)the activities of, and standards to be maintained by, a licensed trust company, an exempt person or any person who is granted an exemption under section\xa080, including the manner, method and place of conducting trust business;(d)the particulars to be recorded in, or in respect of, books kept by a licensed trust company; and(e)the requirements and restrictions relating to the granting of any unsecured advance, unsecured loan or unsecured credit facility by a licensed trust company.(3)\xa0\xa0Except as otherwise expressly provided in this Act, the regulations made under this Act\xa0—(a)may be of general or specific application;(b)may provide that a contravention of any specified provision thereof shall be an offence; and(c)may provide for penalties not exceeding a fine of $25,000 or imprisonment for a term not exceeding 12\xa0months or both for each offence.'],
#    'amendments': [],
#    'nested_provisions': [],
#    'context': {'part': {'id': 'P110-',
#      'number': 'PART 10',
#      'header': 'MISCELLANEOUS'},
#     'division': None,
#     'section': None}}],
#  'schedules': [{'id': 'No ID', 'content': ''},
#   {'id': 'No ID', 'content': ''},
#   {'id': 'No ID', 'content': ''},
#   {'id': 'No ID', 'content': ''}],
#  'legislative_histories': [{'id': 'xv-', 'content': ''},
#   {'id': 'xv-ta-oc2-', 'content': ''}],
#  'comparative_tables': [{'id': 'xy-', 'content': ''}]}

# %%
human_message_template = "This is the provision: REPLACE"

# %%
# Expect dictionaries
answers = []

# %%
def invoke(prompt):
    answer = chain.invoke({"text": prompt})
    return answer

# %%
# convert provision text to plain text
for n, provision in enumerate(test_act['provisions']):
    print(f'Processing provision no. {n}')
    num = provision['number']
    text = provision['text'][0]
    prompt = human_message_template.replace('REPLACE', text)
    try:
        answer = invoke(prompt)
    except Exception as e:
        print(e)
        # We try again
        try:
            answer = invoke(prompt)
        except Exception as e:
            print(e)
            print('Failed to get answer for provision', num)
            answer = None
    print(num, ' - ', answer)
    to_add = {
        'num': num,
        'text': text,
        'return': answer
    }
    answers.append(to_add)
    # so we don't hit the rate limit
    time.sleep(5)
# Out:
# Processing provision no. 0
# 1  -  scenario='A company is established under the Trust Companies Act 2005.' outcome='The company is a trust company.' edge_case='The company is not a trust company, but it is established under the Trust Companies Act 2005.'
# Processing provision no. 1
# 2  -  scenario='A foreign lawyer is trying to understand the definition of an advocate and solicitor in the context of the Monetary Authority of Singapore Act.' outcome='The lawyer understands that an advocate and solicitor refers to an advocate and solicitor of the Supreme Court or a foreign lawyer as defined in section 2(1) of the Legal Profession Act 1966.' edge_case='A foreign lawyer is trying to understand the definition of an advocate and solicitor in the context of the Monetary Authority of Singapore Act.'
# Processing provision no. 2
# 3  -  scenario='A foreign company wants to establish a trust business in Singapore.' outcome='The company will be guilty of an offence and liable to a fine and/or imprisonment.' edge_case='A foreign company wants to establish a trust business in Singapore without obtaining a license.'
# Processing provision no. 3
# 4  -  scenario='A trust company applies for a trust business licence, and the application is complete and accurate.' outcome='The Authority requests the additional information and the applicant provides it, and the application is approved.' edge_case='A trust company applies for a trust business licence, but the application is incomplete, and the Authority requests additional information.'
# Processing provision no. 4
# 5  -  scenario='The applicant is a company incorporated under the Companies Act 1967, but the Authority is not satisfied as to the educational or other qualification or experience of the officers or employees of the applicant.' outcome='The Authority refuses to grant the trust business licence.' edge_case='A company incorporated under the Companies Act 1967 applies for a trust business licence, but the Authority is not satisfied as to the educational or other qualification or experience of the officers or employees of the applicant.'
# Processing provision no. 5
# 6  -  scenario='A licensed trust company pays a licence fee to the Authority, but its licence is revoked during the period to which the licence fee relates.' outcome='The licence fee paid is not refunded or remitted.' edge_case='A licensed trust company has its licence revoked during the period to which the licence fee relates.'
# Processing provision no. 6
# 7  -  scenario="A trust company is granted a trust business licence with a condition that it must maintain a minimum capital requirement of $1 million. The trust company's capital falls below the required amount due to unforeseen market fluctuations." outcome='The Authority revokes the trust business licence, and the trust company is liable for an offence.' edge_case="A trust company is granted a trust business licence with a condition that it must maintain a minimum capital requirement of $1 million. However, the trust company's capital falls below the required amount due to unforeseen market fluctuations."
# Processing provision no. 7
# 8  -  scenario='A person applies for a trust business licence, but provides false information about their business experience, which is a material particular.' outcome='The person is convicted of an offence and faces a fine not exceeding $50,000 or imprisonment for a term not exceeding 12 months or both.' edge_case='A person submits an application for a trust business licence, but intentionally omits to disclose a prior criminal conviction, which is a material fact.'
# Processing provision no. 8
# 9  -  scenario='A licensed trust company has ceased to carry on its trust business and is required to provide particulars of the event to the Authority.' outcome='The licensed trust company is guilty of an offence.' edge_case='A licensed trust company has ceased to carry on its trust business and failed to provide particulars of the event to the Authority within the prescribed timeframe.'
# Processing provision no. 9
# 10  -  scenario='A licensed trust company is in the process of being wound up or otherwise dissolved, whether in Singapore or elsewhere.' outcome='The trust business licence of the licensed trust company lapses.' edge_case='A licensed trust company is wound up or otherwise dissolved, whether in Singapore or elsewhere.'
# Processing provision no. 10
# 11  -  scenario='A licensed trust company is a trustee of a trust that remains in whole or in part unadministered.' outcome='The licensed trust company is guilty of an offence and is liable to a fine not exceeding $25,000.' edge_case='A licensed trust company is about to cease its trust business without the sanction of the court.'
# Processing provision no. 11
# 12  -  scenario='A licensed trust company is found to have breached a provision of this Act, and the Authority initiates winding-up proceedings under the Insolvency, Restructuring and Dissolution Act 2018.' outcome="The court grants the winding up of the licensed trust company, and the liquidator is required to provide the Authority with information about the company's affairs." edge_case='A licensed trust company has contravened a provision of this Act, and the Authority applies for its winding up under the Insolvency, Restructuring and Dissolution Act 2018.'
# Processing provision no. 12
# 13  -  scenario='A licensed trust company wants to appoint a new resident manager or director.' outcome='The licensed trust company is guilty of an offence and is liable on conviction to a fine not exceeding $50,000.' edge_case='A licensed trust company appoints a person as its resident manager or director without obtaining the approval of the Authority.'
# Processing provision no. 13
# 14  -  scenario='A licensed trust company has an officer who has been convicted of an offence involving fraud or dishonesty.' outcome='The Authority directs the licensed trust company to remove the officer from office or employment.' edge_case='The officer of a licensed trust company has been convicted of an offence involving fraud or dishonesty.'
# Processing provision no. 14
# 15  -  scenario='A bank licensed under the Banking Act 1970 provides trust administration services which are procedural and non-discretionary.' outcome='The bank is exempt from the requirement to hold a trust business licence.' edge_case='The bank provides trust administration services that are discretionary.'
# Processing provision no. 15
# 16  -  scenario='A person acquires 25% of the total number of issued shares in a licensed trust company incorporated in Singapore without obtaining the prior approval of the Authority.' outcome='The person is in breach of section 16(1) of the Act.' edge_case='A person becomes a 20% controller of a licensed trust company incorporated in Singapore without obtaining the prior approval of the Authority.'
# Processing provision no. 16
# 17  -  scenario='A licensed trust company is facing financial difficulties and a new investor is needed to inject capital. However, the investor has a history of unethical business practices.' outcome="The Authority grants approval subject to conditions that restrict the person's disposal or further acquisition of shares or voting power in the licensed trust company." edge_case='A person with a questionable past applies for approval to acquire a significant stake in a licensed trust company.'
# Processing provision no. 17
# 18  -  scenario='The Authority is considering serving a notice of objection on a person who has failed to comply with a condition of approval, and is deciding whether to give them an opportunity to be heard.' outcome='The person is given an opportunity to be heard, except in circumstances where they are being wound up, in bankruptcy proceedings, or have been convicted of an offence involving fraud or dishonesty.' edge_case='The Authority serves a written notice of objection on a person mentioned in section 16, citing non-compliance with a condition of approval imposed under section 17(2).'
# Processing provision no. 18
# 19  -  scenario="A licensed trust company has multiple controllers, each holding 25% of the company's shares, and the Authority requests information about the controllers and their control quantities." outcome='The licensed trust company must provide information to the Authority about all its controllers, including their respective quantities of control.' edge_case="A licensed trust company has multiple controllers, each holding 25% of the company's shares."
# Processing provision no. 19
# 20  -  scenario="A person holds more than 15% of the shares in a licensed trust company without the Authority's approval." outcome='The person is not guilty of an offence under section 20(1) of the Act.' edge_case='A person is accused of contravening section 16(1) of the Act, but claims they were not aware of the contravention and took corrective action within 14 days of becoming aware.'
# Processing provision no. 20
# 21  -  scenario='A licensed trust company is considering acquiring shares in a corporation and wants to know if it needs to obtain prior approval from the Authority.' outcome='The licensed trust company is guilty of an offence and is liable to a fine not exceeding $50,000.' edge_case='A licensed trust company acquires 25% of the total number of issued shares in a corporation without obtaining prior approval from the Authority.'
# Processing provision no. 21
# 21A  -  scenario='A licensed trust company is experiencing financial difficulties and the Authority needs to take control of its business to protect the interests of its clients.' outcome="The Authority appoints a statutory adviser or a statutory manager to oversee the licensed trust company's business." edge_case='A licensed trust company is facing financial difficulties and the Authority has assumed control of its business under section 21C.'
# Processing provision no. 22
# 21B  -  scenario='A licensed trust company is experiencing financial difficulties and is unsure about its ability to meet its obligations.' outcome='The trust company is found guilty of an offence and is liable to a fine not exceeding $50,000, and a further fine of $5,000 for every day or part of a day during which the offence continues after conviction.' edge_case='A licensed trust company is on the brink of insolvency and has not informed the Authority, despite being legally obligated to do so.'
# Processing provision no. 23
# 21C  -  scenario='A licensed trust company is experiencing financial difficulties and informs the Authority of its situation.' outcome='The Authority exercises its powers under subsection (2) to require the licensed trust company to take certain actions or to appoint a statutory adviser or statutory manager.' edge_case='A licensed trust company informs the Authority that it is or is likely to become insolvent, or that it is or is likely to become unable to meet its obligations, or that it has suspended or is about to suspend payments.'
# Processing provision no. 24
# 21D  -  scenario='The Authority or statutory manager has assumed control of the relevant business of a licensed trust company, and a person who was appointed as the chief executive or a director of the licensed trust company before the assumption of control is trying to exercise their powers after the assumption of control.' outcome="The person's appointment is deemed to be revoked, and any act or purported act of the person is invalid and of no effect." edge_case='A licensed trust company is under the control of the Authority or statutory manager, and a person who was appointed as the chief executive or a director of the licensed trust company before the assumption of control is trying to act as such after the assumption of control.'
# Processing provision no. 25
# 21E  -  scenario='The licensed trust company is initially poorly managed, but after the Authority assumes control, it is restructured and improved, and the Authority is satisfied that it is no longer necessary to maintain control.' outcome='The Authority ceases to be in control of the licensed trust company.' edge_case='The Authority assumes control of a licensed trust company due to concerns about its management, but later determines that the concerns have been addressed and it is no longer necessary to maintain control.'
# Processing provision no. 26
# 21F  -  scenario='The Authority or statutory manager takes control of a licensed trust company and requests information from the former chief executive, who is reluctant to provide the information.' outcome='The Authority or statutory manager obtains a court order directing the former chief executive to provide the information, and the former chief executive is found guilty of an offence for failing to comply with the court order.' edge_case='A former chief executive of a licensed trust company refuses to provide information to the Authority or statutory manager, claiming that the information is confidential.'
# Processing provision no. 27
# 21G  -  scenario='The Authority has assumed control of the business of a licensed trust company due to financial difficulties.' outcome='The Authority fixes the remuneration and expenses to be paid to the statutory manager or adviser appointed by the Authority.' edge_case='The licensed trust company is in financial distress and the Authority has assumed control of its business.'
# Processing provision no. 28
# 21H  -  scenario='A trust company, XYZ Trust, is transferring its business to a licensed trust company, ABC Trust. The transfer involves a complex mix of property, rights, and obligations, including debentures and liabilities.' outcome="The Court clarifies the meaning of 'business' and 'property' in the context of the transfer, ensuring a smooth transfer of the business." edge_case="A trust company is transferring its business to a licensed trust company, but the transferor's business includes a complex web of property, rights, and obligations that need to be clarified under this provision."
# Processing provision no. 29
# 21I  -  scenario='A licensed trust company wants to transfer its trust business to another company.' outcome='The transfer is not approved by the Authority.' edge_case='A licensed trust company wants to transfer its trust business to another company, but the Authority has not yet given its consent.'
# Processing provision no. 30
# 21J  -  scenario='A transferor applies to the Court for approval of a transfer of business under this Part' outcome='The Court may refuse to approve the transfer under subsection (5)(b)' edge_case='A transferor fails to lodge a report with the Authority as required under subsection (2)(a)'
# Processing provision no. 31
# 22  -  scenario='A wealthy businessman passes away, leaving behind a complex estate with multiple beneficiaries and creditors. The licensed trust company, which is a subsidiary of a large bank, is appointed as the executor of the will.' outcome='The court grants probate and the licensed trust company is able to exercise and discharge all the powers and duties of an executor.' edge_case='The licensed trust company is a subsidiary of a large bank and the testator was a prominent businessman with complex financial affairs.'
# Processing provision no. 32
# 23  -  scenario='A person is entitled to apply for probate of a will without leave being reserved to any other person, but the person is absent from Singapore and wants to authorise a licensed trust company to apply to the court for a grant of administration with the will annexed.' outcome='The person authorises a licensed trust company to apply to the court for a grant of administration with the will annexed.' edge_case='A person is entitled to apply for probate of a will without leave being reserved to any other person, but the person is absent from Singapore.'
# Processing provision no. 33
# 24  -  scenario='A licensed trust company is applying for probate or letters of administration, and the officer of the company is making the application on behalf of the company.' outcome='The application is rejected due to lack of authorisation.' edge_case='A licensed trust company is empowered to apply for probate or letters of administration, but the officer of the company is not duly authorised to make the application.'
# Processing provision no. 34
# 25  -  scenario='A licensed trust company is appointed as a receiver by the court to manage the estate of a deceased person.' outcome='The licensed trust company is not required to provide security for the due performance of its duties.' edge_case='A licensed trust company is appointed as a receiver and is required to provide security for the due performance of its duties.'
# Processing provision no. 35
# 26  -  scenario='A licensed trust company is appointed as a guardian of the person of an infant, which is prohibited by the provision.' outcome='The licensed trust company is guilty of an offence.' edge_case='A licensed trust company is appointed as a guardian of the person of an infant.'
# Processing provision no. 36
# 27  -  scenario='John, an employee of XYZ Trust, wants to purchase some capital markets products for his own account, but there are still some instructions to purchase the same class of capital markets products for the account of the trust that have not been fulfilled.' outcome='John will be guilty of an offence and shall be liable to a fine not exceeding $50,000 or to imprisonment for a term not exceeding 3 years or to both.' edge_case='A licensed trust company, XYZ Trust, has an employee, John, who is involved in the management of the assets of an express trust. John wants to purchase some capital markets products for his own account, but there are still some instructions to purchase the same class of capital markets products for the account of the trust that have not been fulfilled.'
# Processing provision no. 37
# 28  -  scenario='A licensed trust company is audited and found to have inadequate bookkeeping practices, putting its license at risk.' outcome='The licensed trust company is fined $50,000 and required to rectify the issue.' edge_case='A licensed trust company fails to keep proper books and records, leading to inaccurate financial reporting and potential legal issues.'
# Processing provision no. 38
# 29  -  scenario="A licensed trust company's auditor resigns, and the company fails to appoint a new auditor within a reasonable timeframe." outcome='The Authority directs the licensed trust company to remove the auditor and appoint another one.' edge_case='The licensed trust company fails to appoint an auditor after the previous auditor ceases to act.'
# Processing provision no. 39
# 30  -  scenario='A licensed trust company is required to prepare a true and fair profit and loss account and a balance sheet in relation to its business made up to the last day of the financial year, and lodge it with the Authority within the specified timeframe.' outcome='The licensed trust company is guilty of an offence and is liable to a fine not exceeding $500 for every day or part of a day that the lodgment is late, subject to a maximum fine of $50,000.' edge_case='A licensed trust company fails to lodge the profit and loss account and balance sheet with the Authority within the specified timeframe.'
# Processing provision no. 40
# 31  -  scenario="A licensed trust company's auditor discovers a material irregularity in the company's accounts during an audit." outcome='The auditor immediately reports the irregularity to the Authority in writing.' edge_case="Auditor of a licensed trust company discovers a material irregularity in the company's accounts that may jeopardise the moneys or assets of a protected party."
# Processing provision no. 41
# 32  -  scenario="The licensed trust company is experiencing financial difficulties and is unable to lodge the auditor's report on time, leading to the Authority's intervention." outcome='The Authority directs the licensed trust company to pay the costs and expenses of the auditor, and the company fails to comply with the direction.' edge_case="A licensed trust company fails to lodge an auditor's report under section 31, and the Authority appoints an auditor to examine and audit the company's books."
# Processing provision no. 42
# 33  -  scenario='A licensed trust company is undergoing an audit and an employee is trying to prevent the audit from being carried out properly.' outcome='The employee is guilty of an offence and is liable to a fine not exceeding $50,000 or imprisonment for a term not exceeding 2 years or both.' edge_case='A licensed trust company is being audited and an employee, with intent to obstruct the audit, destroys a crucial book relating to the business.'
# Processing provision no. 43
# 34  -  scenario='A licensed trust company has a complex system of checks and balances in place to prevent falsification of books, but an employee finds a way to exploit a vulnerability.' outcome="The trust company is held liable for the employee's actions and faces legal consequences." edge_case='A licensed trust company has a disgruntled employee who intentionally falsifies the books to embezzle funds.'
# Processing provision no. 44
# 35  -  scenario="An auditor's employee is working on a project and needs to discuss some confidential information with a colleague, but is unsure if it is allowed." outcome='The employee is guilty of an offence and liable to a fine not exceeding $25,000.' edge_case="Auditor's employee accidentally shares confidential information with a colleague."
# Processing provision no. 45
# 36  -  scenario='The Authority is conducting an investigation into a licensed trust company and requests the auditor to provide additional information.' outcome='The auditor submits the requested information, but clarifies the scope of the request with the Authority.' edge_case='The Authority requests an auditor to submit additional information, but the auditor is unsure about the scope of the request.'
# Processing provision no. 46
# 37  -  scenario="An auditor submits a report to the Authority, which includes a statement that is later found to be false and damaging to a licensed trust company's reputation." outcome='The auditor is not liable for defamation.' edge_case="Auditor makes a statement about a licensed trust company in a report to the Authority, which is later found to be false and damaging to the company's reputation."
# Processing provision no. 47
# 38  -  scenario='A person is required to disclose information to the Authority under this Part, but is concerned that the disclosure might tend to incriminate them.' outcome='The statement is not admissible in evidence against the person in criminal proceedings other than proceedings under this Act.' edge_case='A person is asked to disclose information that might incriminate them, but claims that the statement might tend to incriminate them.'
# Processing provision no. 48
# 39  -  scenario='A court orders an advocate and solicitor to produce a document containing a privileged communication, but the advocate and solicitor refuses to comply, citing legal privilege.' outcome='The advocate and solicitor is obliged to give the name and address of the client, but is not compelled to disclose the privileged communication.' edge_case='An advocate and solicitor is asked to disclose a privileged communication made by a client, but refuses to do so, citing legal privilege.'
# Processing provision no. 49
# 40  -  scenario="The Authority conducts an inspection of a licensed trust company's books under section 40 of the Act." outcome='The Authority obtains a court order to compel the production of the books.' edge_case='A licensed trust company refuses to produce its books to the Authority, citing confidentiality concerns.'
# Processing provision no. 50
# 41  -  scenario='The Authority is investigating a suspected contravention of this Act and requires a person to provide information that is protected by a contractual obligation of secrecy.' outcome='The person is not in breach of the contractual obligation of secrecy and is protected from civil or criminal action for providing the information.' edge_case='The Authority conducts an investigation under conditions of secrecy to ensure compliance with this Act, and in doing so, requires a person to provide information that is protected by a contractual obligation of secrecy.'
# Processing provision no. 51
# 42  -  scenario='A company is suspected of violating a regulation, and the Authority launches an investigation. The Authority requires the company to produce certain documents, but the company refuses, claiming that the Authority does not have the power to require it.' outcome='The Authority takes the person to court, and the court rules that the Authority has the power to require the information or book.' edge_case='A person refuses to provide information or produce a book, claiming that the Authority does not have the power to require it.'
# Processing provision no. 52
# 43  -  scenario='The Authority receives a tip that a book required to be produced under section 42 is being hidden in a private residence, and the owner of the residence is suspected to be non-compliant with the production requirement.' outcome='The Authority obtains a warrant to search the premises and seizes the book.' edge_case='The Authority has reasonable grounds to suspect that a book required to be produced under section 42 is hidden in a private residence.'
# Processing provision no. 53
# 44  -  scenario='The Authority receives a set of encrypted books during an investigation, and the owner of the books refuses to provide the decryption key.' outcome='The Authority is unable to access the contents of the books and may need to seek additional legal action to compel the production of the decryption key.' edge_case='The Authority takes possession of books under section 42, but the books are encrypted and the decryption key is not provided.'
# Processing provision no. 54
# 45  -  scenario='A person is required to produce a book under section 42, but claims it has been stolen from their office.' outcome='The Authority requires the person to state the place where the book may be found or the person who last had possession, custody or control of the book.' edge_case='A person is required to produce a book under section 42, but claims it has been stolen from their office.'
# Processing provision no. 55
# 46  -  scenario='The person is being investigated by the Authority under this Division and is required to comply with a requirement imposed under section 42, 44(7) or 45.' outcome='The person is guilty of an offence and shall be liable on conviction to a fine not exceeding $50,000 or to imprisonment for a term not exceeding 2 years or to both.' edge_case='A person is being investigated by the Authority under this Division and refuses to comply with a requirement imposed under section 42, 44(7) or 45.'
# Processing provision no. 56
# 47  -  scenario="The parent supervisory authority conducts an inspection of the licensed trust company's branch or office in Singapore, and the licensed trust company refuses to provide access to its books, accounts, and documents." outcome='The licensed trust company is guilty of an offence and is liable to a fine not exceeding $75,000 and a further fine not exceeding $7,500 for every day or part of a day during which the offence continues after conviction.' edge_case='A licensed trust company incorporated outside Singapore refuses to provide access to its books, accounts, and documents to the parent supervisory authority during an inspection.'
# Processing provision no. 57
# 48  -  scenario='A licensed trust company in Singapore receives a written report from the Authority or a parent supervisory authority, and an officer or auditor of the licensed trust company wants to disclose the report to someone outside the company.' outcome='The officer or auditor is not allowed to disclose the report, except in certain circumstances, such as to another officer or auditor of the same licensed trust company, or to the Authority if requested.' edge_case='A licensed trust company in Singapore receives a written report from the Authority or a parent supervisory authority, and an officer or auditor of the licensed trust company wants to disclose the report to someone outside the company.'
# Processing provision no. 58
# 49  -  scenario='A wealthy individual has a trust account with a licensed trust company in Singapore, and a third party requests access to the account information.' outcome='The licensed trust company refuses to disclose the protected information, citing the confidentiality obligations under this provision.' edge_case='A licensed trust company in Singapore receives a request to disclose protected information to a third party.'
# Processing provision no. 59
# 50  -  scenario='An applicant submits an application for a trust business licence, but the Authority refuses to grant it.' outcome='The applicant appeals to the Minister.' edge_case='The Authority refuses to grant a trust business licence to an applicant.'
# Processing provision no. 60
# 51  -  scenario='A foreign national is denied a business license by the Authority, citing a provision that does not apply to foreigners.' outcome='The Minister reverses the decision of the Authority, citing the incorrect application of the law.' edge_case="The appeal is made by a person who is not a citizen of the country, and the Authority's decision is based on a misinterpretation of the law."
# Processing provision no. 61
# 52  -  scenario="A licensed trust company is under investigation by the Appeal Advisory Committee, and a member of the Committee is summoned to give evidence on oath or affirmation regarding the company's trust business." outcome='The Appeal Advisory Committee exercises its power to inquire into the matter and summons the member to produce the necessary documents, emphasizing the importance of safeguarding sources of information.' edge_case='A situation where a member of the Appeal Advisory Committee is summoned to give evidence on oath or affirmation, but refuses to comply, citing concerns about the safeguarding of sources of information.'
# Processing provision no. 62
# 53  -  scenario='A journalist requests information about a government project that could potentially harm the environment.' outcome='The public servant refuses to disclose the information, citing that it is against the public interest.' edge_case='A public servant is asked to disclose information about a government project that could potentially harm the environment.'
# Processing provision no. 63
# 54  -  scenario='The Minister makes regulations that are inconsistent with the provisions of this Part, and an appeal is made to the Minister under this Act.' outcome='The regulations are invalid and of no effect.' edge_case='The Minister makes regulations that are ultra vires, exceeding the scope of the enabling legislation.'
# Processing provision no. 64
# 55  -  scenario='A licensed trust company applies to be registered as a shareholder in a company.' outcome="The company is not entitled to object to the entry of the licensed trust company's name in its books." edge_case="A licensed trust company is listed as a shareholder in a company's books."
# Processing provision no. 65
# 56  -  scenario='A wealthy businessman wants to appoint a licensed trust company as a trustee to manage his estate.' outcome='The court refuses to appoint the licensed trust company as a trustee due to the prohibition in the trust instrument.' edge_case='A wealthy businessman wants to appoint a licensed trust company as a trustee to manage his estate, but the trust instrument explicitly forbids the appointment of a company.'
# Processing provision no. 66
# 57  -  scenario='A wealthy individual wants to acquire a property in joint tenancy with a licensed trust company, acting in a fiduciary capacity, to manage their assets.' outcome='The licensed trust company, acting in a fiduciary capacity, successfully acquires and holds the property in joint tenancy.' edge_case='A licensed trust company, acting in a fiduciary capacity, acquires a property in joint tenancy with a private individual.'
# Processing provision no. 67
# 58  -  scenario='A wealthy businessman is going abroad for an extended period and wants to ensure his assets are managed properly while he is away.' outcome="The licensed trust company is able to exercise all the powers conferred upon it by the deed, including selling some of the businessman's assets to pay off his debts." edge_case='A wealthy businessman appoints a licensed trust company as his attorney to manage his assets while he is abroad.'
# Processing provision no. 68
# 59  -  scenario='A licensed trust company receives moneys, property, securities, specified securities-based derivatives contracts and units in a collective investment scheme in a fiduciary capacity.' outcome='The licensed trust company is guilty of an offence and is liable to a fine not exceeding $50,000.' edge_case='A licensed trust company mixes its own assets with those of its clients in a fiduciary capacity.'
# Processing provision no. 69
# 60  -  scenario='A trust is constituted in Singapore and the licensed trust company holds the moneys and assets for more than 6 years without being claimed by the person entitled to them.' outcome='The licensed trust company must pay the moneys and assets into court under section 62 of the Trustees Act 1967.' edge_case='A licensed trust company holds unclaimed moneys and assets of a trust constituted in Singapore for more than 6 years.'
# Processing provision no. 70
# 61  -  scenario="An officer of a licensed trust company is responsible for maintaining the company's financial records. One day, the officer intentionally omits a transaction from the records to conceal a personal loan from the company." outcome='The officer is guilty of an offence and is liable to a fine not exceeding $100,000 or imprisonment for a term not exceeding 2 years or both.' edge_case="An officer of a licensed trust company intentionally omits a transaction from the company's records."
# Processing provision no. 71
# 62  -  scenario='A person is required to provide information to the Authority under this Act, but they intentionally provide false information to avoid penalties.' outcome='The person is guilty of an offence and is liable to a fine not exceeding $25,000 or imprisonment for a term not exceeding 2 years or both.' edge_case='A person provides false information to the Authority, claiming that they have complied with a certain requirement, when in fact they have not.'
# Processing provision no. 72
# 63  -  scenario='A defendant is accused of an offence under this Act, and the prosecution seeks to try the case in a District Court, despite the Criminal Procedure Code 2010 suggesting otherwise.' outcome='The District Court has jurisdiction to try the offence and impose the full penalty or punishment.' edge_case='A situation where a defendant is accused of an offence under this Act, and the prosecution seeks to try the case in a District Court, despite the Criminal Procedure Code 2010 suggesting otherwise.'
# Processing provision no. 73
# 64  -  scenario="A company's management is aware of the environmental regulations but chooses to ignore them, resulting in significant pollution." outcome='The CEO, as an officer of the company, is guilty of the offence and liable to be punished accordingly.' edge_case="A company's CEO, who is also a member of the committee of management, knowingly allows the company to violate environmental regulations, resulting in significant pollution."
# Processing provision no. 74
# 65  -  scenario='The officer of a licensed trust company was responsible for ensuring compliance with the Act, but failed to do so, and submitted an inaccurate statement.' outcome='The officer was found guilty of an offence and was liable to a fine not exceeding $100,000 or to imprisonment for a term not exceeding 2 years or to both.' edge_case='The officer of a licensed trust company failed to take reasonable steps to secure compliance with a provision of this Act, and submitted an inaccurate statement.'
# Processing provision no. 75
# 66  -  scenario='A person is accused of an offence under this Act for which no penalty is expressly provided.' outcome='The person is liable on conviction to a fine not exceeding $12,500.' edge_case='A person is found guilty of an offence under this Act for which no penalty is expressly provided.'
# Processing provision no. 76
# 67  -  scenario='A corporation is convicted of an offence under this Act, and the court is determining the penalty.' outcome='The court imposes a fine not exceeding 2 times the maximum amount that the court could, but for this subsection, impose as a fine for that offence.' edge_case='A corporation is convicted of an offence under this Act, and the court is determining the penalty.'
# Processing provision no. 77
# 68  -  scenario='A suspect is caught by a police officer for an offence under this Act, but the Public Prosecutor has not given consent for the proceedings.' outcome='The proceedings are rejected by the court due to lack of consent from the Public Prosecutor.' edge_case='A police officer wants to initiate proceedings against a suspect for an offence under this Act without the consent of the Public Prosecutor.'
# Processing provision no. 78
# 69  -  scenario='A person is suspected of having committed an offence under this Act, which was compoundable at the time it was committed, but has since ceased to be compoundable.' outcome='The Authority compounds the offence by collecting a sum of money not exceeding one half of the amount of the maximum fine prescribed for that offence at the time it was committed.' edge_case='A person is reasonably suspected of having committed an offence under this Act, but the offence is no longer compoundable.'
# Processing provision no. 79
# 70  -  scenario='A foreign trust company wants to operate in Singapore, but does not want to obtain a license. It claims that a treaty between Singapore and its home country exempts it from licensing requirements.' outcome='The Authority grants an exemption to the foreign trust company, allowing it to operate in Singapore without a license.' edge_case='A foreign trust company wants to operate in Singapore without obtaining a license, relying on an exemption under a treaty.'
# Processing provision no. 80
# 71  -  scenario='A person living in a remote area is given an opportunity to be heard by the Authority regarding a decision that affects their livelihood.' outcome='The Authority prescribes a unique manner of giving the person an opportunity to be heard, such as through a video conference.' edge_case='A person is given an opportunity to be heard by the Authority in a highly unusual circumstance, such as a remote island with limited communication infrastructure.'
# Processing provision no. 81
# 72  -  scenario='A licensed trust company is found to have contravened a provision of this Act, and the Authority is considering taking disciplinary action.' outcome='The Authority reprimands the licensed trust company.' edge_case='A licensed trust company fails to comply with a written direction issued by the Authority, and the Authority is considering reprimanding the company.'
# Processing provision no. 82
# 73  -  scenario='The Authority appoints an officer to grant exemptions to specific persons under the Act, but the officer starts to abuse the power by granting exemptions to unauthorized persons.' outcome='The exemption is revoked, and the officer is held accountable for the misuse of power.' edge_case='A situation where the Authority appoints an officer to grant an exemption to a specific person, but the officer misuses the power and grants the exemption to an unauthorized person.'
# Processing provision no. 83
# 74  -  scenario='A company is operating in a regulatory environment where the Authority has issued codes, guidelines, policy statements, and practice notes to provide guidance on the application of this Act.' outcome='The Authority issues a no-action letter to the company, stating that it will not institute proceedings against the company in respect of the particular state of affairs or conduct.' edge_case='A company is unsure about the application of a provision of this Act and seeks guidance from the Authority.'
# Processing provision no. 84
# 75  -  scenario='A licensed trust company is operating in a way that is detrimental to the public interest, and the Authority needs to take action to protect the public.' outcome='The Authority publishes information about the revocation of the licence, including the reasons for the revocation.' edge_case='A licensed trust company is found to have breached the terms of its licence, and the Authority decides to revoke its licence.'
# Processing provision no. 85
# 76  -  scenario='A licensed trust company is issued a written direction by the Authority to improve its standards of operation, but the company fails to comply, leading to a risk to the public or protected parties.' outcome='The Authority takes enforcement action against the licensed trust company, including imposing a fine of up to $50,000 and further fines of $5,000 for each day the offence continues.' edge_case='A licensed trust company fails to comply with a written direction issued by the Authority, resulting in a significant risk to the public or protected parties.'
# Processing provision no. 86
# 77  -  scenario='A trust business licence holder is about to breach a condition or restriction of their licence, and the Authority applies to the court for an order to restrain the licence holder from carrying on all or any of the trust business.' outcome='The court makes an order restraining the licence holder from carrying on all or any of the trust business.' edge_case='A trust business licence holder is about to breach a condition or restriction of their licence.'
# Processing provision no. 87
# 78  -  scenario='A person has engaged, is engaging or is likely to engage in any conduct that constitutes or would constitute a contravention of this Act.' outcome='The court may grant an injunction restraining the person from engaging in the conduct and, if the court is of the opinion that it is desirable to do so, requiring that person to do any act or thing.' edge_case='A person has engaged, is engaging or is likely to engage in any conduct that constitutes or would constitute a contravention of this Act.'
# Processing provision no. 88
# 79  -  scenario='The Authority needs to serve a notice on a foreign company that has no presence in Singapore.' outcome="The Authority sends a notice to the foreign company's registered office in the place of its incorporation." edge_case='A foreign company has no registered office in Singapore and does not maintain a place of business in Singapore.'
# Processing provision no. 89
# 80  -  scenario='A person applies to the Authority for an exemption from a provision of this Act, and the Authority grants the exemption subject to certain conditions.' outcome='The person is guilty of an offence if they contravene the condition.' edge_case='A person is exempt from a provision of this Act, but the exemption is subject to a condition that they must comply with certain requirements.'
# Processing provision no. 90
# 81  -  scenario='The Minister seeks to update the exempted goods list to reflect changes in international trade agreements.' outcome='The amendment is gazetted and presented to Parliament.' edge_case='The Minister amends Schedule A to include a new category of exempted goods.'
# Processing provision no. 91
# 82  -  scenario='A licensed trust company is granted an exemption under section 80, but fails to maintain the required standards, leading to a breach of regulations.' outcome='The Authority revokes the exemption and imposes penalties on the licensed trust company.' edge_case='A licensed trust company is granted an exemption under section 80, but fails to maintain the required standards, leading to a breach of regulations.'

# %%
# # save answers as jsonlines file
# # This is the first run
# with open('tca2015-l4_scenario_test-simple.jl', 'w') as f:
#     for answer in answers:
#         pydantic_class = answer['return']
#         # convert pydantic class to tuple
#         tup = (pydantic_class.scenario, pydantic_class.outcome, pydantic_class.edge_case)
#         answer['return'] = tup
#         f.write(json.dumps(answer))

# %%
# save answers as jsonlines file
# This is the second run where I changed the prompts to get it to provide a richer set of facts
# No discernible difference despite the changes
with open('tca2015-l4_scenario_test-comprehensive.jl', 'w') as f:
    for answer in answers:
        pydantic_class = answer['return']
        # convert pydantic class to tuple
        tup = (pydantic_class.scenario, pydantic_class.outcome, pydantic_class.edge_case)
        answer['return'] = tup
        f.write(json.dumps(answer))
